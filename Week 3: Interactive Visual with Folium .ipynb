# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Launch Sites Locations Analysis with Folium**

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# The launch success rate may depend on many factors such as payload mass, orbit type, and so on. It may also depend on the location and proximities of a launch site, i.e., the initial position of rocket trajectories. Finding an optimal location for building a launch site certainly involves many factors and hopefully we could discover some of the factors by analyzing the existing launch site locations.

# %% [markdown]
# In the previous exploratory data analysis labs, you have visualized the SpaceX launch dataset using `matplotlib` and `seaborn` and discovered some preliminary correlations between the launch site and success rates. In this lab, you will be performing more interactive visual analytics using `Folium`.

# %% [markdown]
# ## Objectives

# %% [markdown]
# This lab contains the following tasks:
#
# *   **TASK 1:** Mark all launch sites on a map
# *   **TASK 2:** Mark the success/failed launches for each site on the map
# *   **TASK 3:** Calculate the distances between a launch site to its proximities
#
# After completed the above tasks, you should be able to find some geographical patterns about launch sites.

# %% [markdown]
# Let's first import required Python packages for this lab:

# %%
# !pip3 install folium
# !pip3 install wget

# %%
import folium
import wget
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %% [markdown]
# If you need to refresh your memory about folium, you may download and refer to this previous folium lab:

# %% [markdown]
# [Generating Maps with Python](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module\_3/DV0101EN-3-5-1-Generating-Maps-in-Python-py-v2.0.ipynb)

# %% [markdown]
# ## Task 1: Mark all launch sites on a map

# %% [markdown]
# First, let's try to add each site's location on a map using site's latitude and longitude coordinates

# %% [markdown]
# The following dataset with the name `spacex_launch_geo.csv` is an augmented dataset with latitude and longitude added for each site.

# %%
# Download and read the `spacex_launch_geo.csv`
spacex_csv_file = wget.download('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv')
spacex_df=pd.read_csv(spacex_csv_file)

# %% [markdown]
# Now, you can take a look at what are the coordinates for each site.

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %% [markdown]
# Above coordinates are just plain numbers that can not give you any intuitive insights about where are those launch sites. If you are very good at geography, you can interpret those numbers directly in your mind. If not, that's fine too. Let's visualize those locations by pinning them on a map.

# %% [markdown]
# We first need to create a folium `Map` object, with an initial center location to be NASA Johnson Space Center at Houston, Texas.

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %% [markdown]
# We could use `folium.Circle` to add a highlighted circle area with a text label on a specific coordinate. For example,

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# and you should find a small yellow circle near the city of Houston and you can zoom-in to see a larger circle.

# %% [markdown]
# Now, let's add a circle for each launch site in data frame `launch_sites`

# %% [markdown]
# *TODO:*  Create and add `folium.Circle` and `folium.Marker` for each launch site on the site map

# %% [markdown]
# An example of folium.Circle:

# %% [markdown]
# `folium.Circle(coordinate, radius=1000, color='#000000', fill=True).add_child(folium.Popup(...))`

# %% [markdown]
# An example of folium.Marker:

# %% [markdown]
# `folium.map.Marker(coordinate, icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0), html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'label', ))`

# %%
# Initial the map
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
launch_sites_df
CCAFS_LC_coordinate = [28.562302,-80.577356]
CCAFS_SLC_coordinate = [28.563197,-80.576820]
KSC_coordinate = [28.573255,-80.646895]
VAFB_coordinate = [34.632834,-120.610746]
# For each launch site, add a Circle object based on its coordinate (Lat, Long) values. In addition, add Launch site name as a popup label
circle1  = folium.Circle(CCAFS_LC_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('CCAFS LC-40'))
circle2  = folium.Circle(CCAFS_SLC_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('CCAFS SLC-40'))
circle3  = folium.Circle(KSC_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('KSC LC-39A'))
circle4  = folium.Circle(VAFB_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('VAFB SLC-4E'))
marker1 = folium.map.Marker(
    CCAFS_LC_coordinate,
    # Create an icon as a text label
     icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'CCAFS LC-40',
        )
    )
marker2 = folium.map.Marker(
    CCAFS_SLC_coordinate,
    # Create an icon as a text label
     icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'CCAFS SLC-40',
        )
    )
marker3 = folium.map.Marker(
    KSC_coordinate,
    # Create an icon as a text label
     icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'KSC LC-39A',
        )
    )
marker4 = folium.map.Marker(
    VAFB_coordinate,
    # Create an icon as a text label
     icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'VAFB SLC-4E',
        )
    )
site_map.add_child(circle1)
site_map.add_child(marker1)
site_map.add_child(circle2)
site_map.add_child(marker2)
site_map.add_child(circle3)
site_map.add_child(marker3)
site_map.add_child(circle4)
site_map.add_child(marker4)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# The generated map with marked launch sites should look similar to the following:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_markers.png" />
# </center>

# %% [markdown]
# Now, you can explore the map by zoom-in/out the marked areas
# , and try to answer the following questions:
#
# *   Are all launch sites in proximity to the Equator line?
# *   Are all launch sites in very close proximity to the coast?
#
# Also please try to explain your findings.

# %% [markdown]
# Are all launch sites in proximity to the Equator line? - Yes because the equrator cooredinates are [0,0] and the equator coordinates of all launch sites are close to [0,0].
#
# Are all launch sites in very close proximity to the coast? - Yes because they are right next to the blue in the map which represents the ocean.

# %% [markdown]
# # Task 2: Mark the success/failed launches for each site on the map

# %% [markdown]
# Next, let's try to enhance the map by adding the launch outcomes for each site, and see which sites have high success rates.
# Recall that data frame spacex_df has detailed launch records, and the `class` column indicates if this launch was successful or not

# %%
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class
# 46    KSC LC-39A  28.573255 -80.646895      1
# 47    KSC LC-39A  28.573255 -80.646895      1
# 48    KSC LC-39A  28.573255 -80.646895      1
# 49  CCAFS SLC-40  28.563197 -80.576820      1
# 50  CCAFS SLC-40  28.563197 -80.576820      1
# 51  CCAFS SLC-40  28.563197 -80.576820      0
# 52  CCAFS SLC-40  28.563197 -80.576820      0
# 53  CCAFS SLC-40  28.563197 -80.576820      0
# 54  CCAFS SLC-40  28.563197 -80.576820      1
# 55  CCAFS SLC-40  28.563197 -80.576820      0

# %% [markdown]
# Next, let's create markers for all launch records.
# If a launch was successful `(class=1)`, then we use a green marker and if a launch was failed, we use a red marker `(class=0)`

# %% [markdown]
# Note that a launch only happens in one of the four launch sites, which means many launch records will have the exact same coordinate. Marker clusters can be a good way to simplify a map containing many markers having the same coordinate.

# %% [markdown]
# Let's first create a `MarkerCluster` object

# %%
marker_cluster = MarkerCluster()

# %% [markdown]
# *TODO:* Create a new column in `launch_sites` dataframe called `marker_color` to store the marker colors based on the `class` value

# %%
# Apply a function to check the value of `class` column
# If class=1, marker_color value will be green
# If class=0, marker_color value will be red

# %%
# Function to assign color to launch outcome
def assign_marker_color(launch_outcome):
    if launch_outcome == 1:
        return 'green'
    else:
        return 'red'
    
spacex_df['marker_color'] = spacex_df['class'].apply(assign_marker_color)
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class marker_color
# 46    KSC LC-39A  28.573255 -80.646895      1        green
# 47    KSC LC-39A  28.573255 -80.646895      1        green
# 48    KSC LC-39A  28.573255 -80.646895      1        green
# 49  CCAFS SLC-40  28.563197 -80.576820      1        green
# 50  CCAFS SLC-40  28.563197 -80.576820      1        green
# 51  CCAFS SLC-40  28.563197 -80.576820      0          red
# 52  CCAFS SLC-40  28.563197 -80.576820      0          red
# 53  CCAFS SLC-40  28.563197 -80.576820      0          red
# 54  CCAFS SLC-40  28.563197 -80.576820      1        green
# 55  CCAFS SLC-40  28.563197 -80.576820      0          red

# %% [markdown]
# *TODO:* For each launch result in `spacex_df` data frame, add a `folium.Marker` to `marker_cluster`

# %%
# Add marker_cluster to current site_map
site_map.add_child(marker_cluster)

# for each row in spacex_df data frame
# create a Marker object with its coordinate
# and customize the Marker's icon property to indicate if this launch was successed or failed, 
# e.g., icon=folium.Icon(color='white', icon_color=row['marker_color']
for index, row in spacex_df.iterrows():
    # TODO: Create and add a Marker cluster to the site map
    folium.Marker([row['Lat'],row['Long']], icon=folium.Icon(color='white', icon_color=row['marker_color'])).add_to(marker_cluster)
    #marker_cluster.add_child(marker_cluster)
    site_map.add_child(marker_cluster)
    
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Your updated map may look like the following screenshots:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster.png" />
# </center>

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster_zoomed.png" />
# </center>

# %% [markdown]
# From the color-labeled markers in marker clusters, you should be able to easily identify which launch sites have relatively high success rates.

# %% [markdown]
# # TASK 3: Calculate the distances between a launch site to its proximities

# %% [markdown]
# Next, we need to explore and analyze the proximities of launch sites.

# %% [markdown]
# Let's first add a `MousePosition` on the map to get coordinate for a mouse over a point on the map. As such, while you are exploring the map, you can easily find the coordinates of any points of interests (such as railway)

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %% [markdown]
# You can calculate the distance between two points on the map based on their `Lat` and `Long` values using the following method:

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# *TODO:* Mark down a point on the closest coastline using MousePosition and calculate the distance between the coastline point and the launch site.

# %%
# find coordinate of the closet coastline
# e.g.,: Lat: 28.56367  Lon: -80.57163
coordinates_coastline_LC = [[28.562302,-80.577356],
                         [28.56336,-80.56794]]
launch_site_lat_LC = coordinates_coastline_LC[0][0]
launch_site_lon_LC = coordinates_coastline_LC[0][1]
coastline_lat_LC = coordinates_coastline_LC[1][0]
coastline_lon_LC = coordinates_coastline_LC[1][1]

distance_coastline_LC = calculate_distance(launch_site_lat_LC, launch_site_lon_LC, coastline_lat_LC, coastline_lon_LC)

# %% [markdown]
# *TODO:* After obtained its coordinate, create a `folium.Marker` to show the distance

# %%
# Create and add a folium.Marker on your selected closest coastline point on the map
# Display the distance between coastline point and launch site using the icon property 
# for example
distance_coastline_marker_LC = folium.Marker(
    [28.56337,-80.56787], # where the km value is placed
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline_LC)
        )
    )
site_map.add_child(distance_coastline_marker_LC)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# *TODO:* Draw a `PolyLine` between a launch site to the selected coastline point

# %%
# Create a `folium.PolyLine` object using the coastline coordinates and launch site coordinate
lines_coastline_LC=folium.PolyLine(locations=coordinates_coastline_LC, weight=1)
site_map.add_child(lines_coastline_LC)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Your updated map with distance line should look like the following screenshot:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_distance.png" />
# </center>

# %% [markdown]
# *TODO:* Similarly, you can draw a line betwee a launch site to its closest city, railway, highway, etc. You need to use `MousePosition` to find the their coordinates on the map first

# %% [markdown]
# A railway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/railway.png" />
# </center>

# %% [markdown]
# A highway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/highway.png" />
# </center>

# %% [markdown]
# A city map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/city.png" />
# </center>

# %%
# Create a marker with distance to a closest city, railway, highway, etc.
# Draw a line between the marker to the launch site

# CCAFS LC-40 Highway Marker
coordinates_highway_LC = [[28.562302,-80.577356],
                            [28.56287,-80.57073]]
launch_site_lat_LC = coordinates_highway_LC[0][0]
launch_site_lon_LC = coordinates_highway_LC[0][1]
highway_lat_LC = coordinates_highway_LC[1][0]
highway_lon_LC = coordinates_highway_LC[1][1]

distance_highway_LC = calculate_distance(launch_site_lat_LC, launch_site_lon_LC, highway_lat_LC, highway_lon_LC)
distance_highway_marker_LC = folium.Marker(
  [28.56287,-80.57073], # where the km value is placed
  icon=DivIcon(
    icon_size=(20,20),
    icon_anchor=(0,0),
    html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_highway_LC)
  )
)
site_map.add_child(distance_highway_marker_LC)
lines_highway_LC=folium.PolyLine(locations=coordinates_highway_LC, weight=1)
site_map.add_child(lines_highway_LC)
#site_map

# CCAFS LC-40 Railway Marker
coordinates_railroad_LC = [[28.562302,-80.577356],
                            [28.57269,-80.58523]]
launch_site_lat_LC = coordinates_railroad_LC[0][0]
launch_site_lon_LC = coordinates_railroad_LC[0][1]
railroad_lat_LC = coordinates_railroad_LC[1][0]
railroad_lon_LC = coordinates_railroad_LC[1][1]

distance_railroad_LC = calculate_distance(launch_site_lat_LC, launch_site_lon_LC, railroad_lat_LC, railroad_lon_LC)
distance_railroad_marker_LC = folium.Marker(
  [28.57269,-80.58523], # where the km value is placed
  icon=DivIcon(
    icon_size=(20,20),
    icon_anchor=(0,0),
    html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_railroad_LC)
  )
)
site_map.add_child(distance_railroad_marker_LC)
lines_railroad_LC=folium.PolyLine(locations=coordinates_railroad_LC, weight=1)
site_map.add_child(lines_railroad_LC)

# CCAFS LC-40 City Marker
coordinates_city_LC = [[28.562302,-80.577356],
                            [28.09742,-80.62592]]
launch_site_lat_LC = coordinates_city_LC[0][0]
launch_site_lon_LC = coordinates_city_LC[0][1]
city_lat_LC = coordinates_city_LC[1][0]
city_lon_LC = coordinates_city_LC[1][1]

distance_city_LC = calculate_distance(launch_site_lat_LC, launch_site_lon_LC, city_lat_LC, city_lon_LC)
distance_city_marker_LC = folium.Marker(
  [28.09742,-80.62592], # where the km value is placed
  icon=DivIcon(
    icon_size=(20,20),
    icon_anchor=(0,0),
    html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_city_LC)
  )
)
site_map.add_child(distance_city_marker_LC)
lines_city_LC=folium.PolyLine(locations=coordinates_city_LC, weight=1)
site_map.add_child(lines_city_LC)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ###### Distance lines for launch site: CCAFS SLC-40

# %%
# Add coastline distance for CCAFS SLC-40
coordinates_coastline_SLC = [[28.563197,-80.576820],
                         [28.56432,-80.56781]]
launch_site_lat_SLC = coordinates_coastline_SLC[0][0]
launch_site_lon_SLC = coordinates_coastline_SLC[0][1]
coastline_lat_SLC = coordinates_coastline_SLC[1][0]
coastline_lon_SLC = coordinates_coastline_SLC[1][1]

distance_coastline_SLC = calculate_distance(launch_site_lat_SLC, launch_site_lon_SLC, coastline_lat_SLC, coastline_lon_SLC)
distance_coastline_marker_SLC = folium.Marker(
    [28.56432,-80.56781], # where the km value is placed
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline_SLC)
        )
    )
site_map.add_child(distance_coastline_marker_SLC)
lines_coastline_SLC=folium.PolyLine(locations=coordinates_coastline_SLC, weight=1)
site_map.add_child(lines_coastline_SLC)

# Add highway distance for CCAFS SLC-40
coordinates_highway_SLC = [[28.563197,-80.576820],
                          [28.56355,-80.57081]]
launch_site_lat_SLC = coordinates_highway_SLC[0][0]
launch_site_lon_SLC = coordinates_highway_SLC[0][1]
highway_lat_SLC = coordinates_highway_SLC[1][0]
highway_lon_SLC = coordinates_highway_SLC[1][1]

distance_highway_SLC = calculate_distance(launch_site_lat_SLC, launch_site_lon_SLC, highway_lat_SLC, highway_lon_SLC)
distance_highway_marker_SLC = folium.Marker(
  [28.56355,-80.57081], # where the km value is placed
  icon=DivIcon(
    icon_size=(20,20),
    icon_anchor=(0,0),
    html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_highway_SLC)
  )
)
site_map.add_child(distance_highway_marker_SLC)
lines_highway_SLC=folium.PolyLine(locations=coordinates_highway_SLC, weight=1)
site_map.add_child(lines_highway_SLC)

# Add railroad distance for CCAFS SLC-40
coordinates_railroad_SLC = [[28.563197,-80.576820],
                           [28.57269,-80.58523]]
launch_site_lat_SLC = coordinates_railroad_SLC[0][0]
launch_site_lon_SLC = coordinates_railroad_SLC[0][1]
railroad_lat_SLC = coordinates_railroad_SLC[1][0]
railroad_lon_SLC = coordinates_railroad_SLC[1][1]

distance_railroad_SLC = calculate_distance(launch_site_lat_SLC, launch_site_lon_SLC, railroad_lat_SLC, railroad_lon_SLC)
distance_railroad_marker_SLC = folium.Marker(
  [28.57269,-80.58523], # where the km value is placed
  icon=DivIcon(
    icon_size=(20,20),
    icon_anchor=(0,0),
    html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_railroad_SLC)
  )
)
site_map.add_child(distance_railroad_marker_SLC)
lines_railroad_SLC=folium.PolyLine(locations=coordinates_railroad_SLC, weight=1)
site_map.add_child(lines_railroad_SLC)

# Add city distance for CCAFS SLC-40
coordinates_city_SLC = [[28.563197,-80.576820],
                       [28.09864,-80.63416]]
launch_site_lat_SLC = coordinates_city_SLC[0][0]
launch_site_lon_SLC = coordinates_city_SLC[0][1]
city_lat_SLC = coordinates_city_SLC[1][0]
city_lon_SLC = coordinates_city_SLC[1][1]

distance_city_SLC = calculate_distance(launch_site_lat_SLC, launch_site_lon_SLC, city_lat_SLC, city_lon_SLC)
distance_city_marker_SLC = folium.Marker(
  [28.09864,-80.63416], # where the km value is placed
  icon=DivIcon(
    icon_size=(20,20),
    icon_anchor=(0,0),
    html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_city_SLC)
  )
)
site_map.add_child(distance_city_marker_SLC)
lines_city_SLC=folium.PolyLine(locations=coordinates_city_SLC, weight=1)
site_map.add_child(lines_city_SLC)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ###### Distance lines for KSC LC-39A

# %%
# Add coastline distance for KSC LC-39A
coordinates_coastline_KSC = [[28.573255,-80.646895],
                             [28.57427,-80.56978]]
launch_site_lat_KSC = coordinates_coastline_KSC[0][0]
launch_site_lon_KSC = coordinates_coastline_KSC[0][1]
coastline_lat_KSC = coordinates_coastline_KSC[1][0]
coastline_lon_KSC = coordinates_coastline_KSC[1][1]

distance_coastline_KSC = calculate_distance(launch_site_lat_KSC, launch_site_lon_KSC, coastline_lat_KSC, coastline_lon_KSC)
distance_coastline_marker_KSC = folium.Marker(
  [28.57427,-80.56978], # where the km value is placed
  icon=DivIcon(
    icon_size=(20,20),
    icon_anchor=(0,0),
    html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline_KSC)
  )
)
site_map.add_child(distance_coastline_marker_KSC)
lines_coastline_KSC=folium.PolyLine(locations=coordinates_coastline_KSC, weight=1)
site_map.add_child(lines_coastline_KSC)

# Add highway distance for KSC LC-39A
coordinates_highway_KSC = [[28.573255,-80.646895],
                           [28.57253,-80.6554]]
launch_site_lat_KSC = coordinates_highway_KSC[0][0]
launch_site_lon_KSC = coordinates_highway_KSC[0][1]
highway_lat_KSC = coordinates_highway_KSC[1][0]
highway_lon_KSC = coordinates_highway_KSC[1][1]

distance_highway_KSC = calculate_distance(launch_site_lat_KSC, launch_site_lon_KSC, highway_lat_KSC, highway_lon_KSC)
distance_highway_marker_KSC = folium.Marker(
  [28.57253,-80.6554], # where the km value is placed
  icon=DivIcon(
    icon_size=(20,20),
    icon_anchor=(0,0),
    html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_highway_KSC)
  )
)
site_map.add_child(distance_highway_marker_KSC)
lines_highway_KSC=folium.PolyLine(locations=coordinates_highway_KSC, weight=1)
site_map.add_child(lines_highway_KSC)

# Add railroad distance for KSC LC-39A
coordinates_railroad_KSC = [[28.573255,-80.646895],
                            [28.57233,-80.65392]]
launch_site_lat_KSC = coordinates_railroad_KSC[0][0]
launch_site_lon_KSC = coordinates_railroad_KSC[0][1]
railroad_lat_KSC = coordinates_railroad_KSC[1][0]
railroad_lon_KSC = coordinates_railroad_KSC[1][1]

distance_railroad_KSC = calculate_distance(launch_site_lat_KSC, launch_site_lon_KSC, railroad_lat_KSC, railroad_lon_KSC)
distance_railroad_marker_KSC = folium.Marker(
  [28.57233,-80.65392], # where the km value is placed
  icon=DivIcon(
    icon_size=(20,20),
    icon_anchor=(0,0),
    html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_railroad_KSC)
  )
)
site_map.add_child(distance_railroad_marker_KSC)
lines_railroad_KSC=folium.PolyLine(locations=coordinates_railroad_KSC, weight=1)
site_map.add_child(lines_railroad_KSC)

# Add city distance for KSC LC-39A
coordinates_city_KSC = [[28.573255,-80.646895],
                        [28.09985,-80.67123]]
launch_site_lat_KSC = coordinates_city_KSC[0][0]
launch_site_lon_KSC = coordinates_city_KSC[0][1]
city_lat_KSC = coordinates_city_KSC[1][0]
city_lon_KSC = coordinates_city_KSC[1][1]

distance_city_KSC = calculate_distance(launch_site_lat_KSC, launch_site_lon_KSC, city_lat_KSC, city_lon_KSC)
distance_city_marker_KSC = folium.Marker(
  [28.09985,-80.67123], # where the km value is placed
  icon=DivIcon(
    icon_size=(20,20),
    icon_anchor=(0,0),
    html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_city_KSC)
  )
)
site_map.add_child(distance_city_marker_KSC)
lines_city_KSC=folium.PolyLine(locations=coordinates_city_KSC, weight=1)
site_map.add_child(lines_city_KSC)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ##### Distance lines for VAFB SLC-4E

# %%
# Add coastline distance for VAFB SLC-4E
coordinates_coastline_VAFB = [[34.632834, -120.610746],
                             [34.63519,-120.62593]]
launch_site_lat_VAFB = coordinates_coastline_VAFB[0][0]
launch_site_lon_VAFB = coordinates_coastline_VAFB[0][1]
coastline_lat_VAFB = coordinates_coastline_VAFB[1][0]
coastline_lon_VAFB = coordinates_coastline_VAFB[1][1]

distance_coastline_VAFB = calculate_distance(launch_site_lat_VAFB, launch_site_lon_VAFB, coastline_lat_VAFB, coastline_lon_VAFB)
distance_coastline_marker_VAFB = folium.Marker(
  [34.63519,-120.62593], # where the km value is placed
  icon=DivIcon(
    icon_size=(20,20),
    icon_anchor=(0,0),
    html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline_VAFB)
  )
)
site_map.add_child(distance_coastline_marker_VAFB)
lines_coastline_VAFB=folium.PolyLine(locations=coordinates_coastline_VAFB, weight=1)
site_map.add_child(lines_coastline_VAFB)

# Add highway distance for VAFB SLC-4E
coordinates_highway_VAFB = [[34.632834, -120.610746],
                           [34.70549,-120.48706]]
launch_site_lat_VAFB = coordinates_highway_VAFB[0][0]
launch_site_lon_VAFB = coordinates_highway_VAFB[0][1]
highway_lat_VAFB = coordinates_highway_VAFB[1][0]
highway_lon_VAFB = coordinates_highway_VAFB[1][1]

distance_highway_VAFB = calculate_distance(launch_site_lat_VAFB, launch_site_lon_VAFB, highway_lat_VAFB, highway_lon_VAFB)
distance_highway_marker_VAFB = folium.Marker(
  [34.70549,-120.48706], # where the km value is placed
  icon=DivIcon(
    icon_size=(20,20),
    icon_anchor=(0,0),
    html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_highway_VAFB)
  )
)
site_map.add_child(distance_highway_marker_VAFB)
lines_highway_VAFB=folium.PolyLine(locations=coordinates_highway_VAFB, weight=1)
site_map.add_child(lines_highway_VAFB)

# Add railroad distance for VAFB SLC-4E
coordinates_railroad_VAFB = [[34.632834, -120.610746],
                            [34.63264,-120.62473]]
launch_site_lat_VAFB = coordinates_railroad_VAFB[0][0]
launch_site_lon_VAFB = coordinates_railroad_VAFB[0][1]
railroad_lat_VAFB = coordinates_railroad_VAFB[1][0]
railroad_lon_VAFB = coordinates_railroad_VAFB[1][1]

distance_railroad_VAFB = calculate_distance(launch_site_lat_VAFB, launch_site_lon_VAFB, railroad_lat_VAFB, railroad_lon_VAFB)
distance_railroad_marker_VAFB = folium.Marker(
  [34.63264,-120.62473], # where the km value is placed
  icon=DivIcon(
    icon_size=(20,20),
    icon_anchor=(0,0),
    html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_railroad_VAFB)
  )
)
site_map.add_child(distance_railroad_marker_VAFB)
lines_railroad_VAFB=folium.PolyLine(locations=coordinates_railroad_VAFB, weight=1)
site_map.add_child(lines_railroad_VAFB)

# Add city distance for VAFB SLC-4E
coordinates_city_VAFB = [[34.632834, -120.610746],
                        [34.94674,-120.439]]
launch_site_lat_VAFB = coordinates_city_VAFB[0][0]
launch_site_lon_VAFB = coordinates_city_VAFB[0][1]
city_lat_VAFB = coordinates_city_VAFB[1][0]
city_lon_VAFB = coordinates_city_VAFB[1][1]

distance_city_VAFB = calculate_distance(launch_site_lat_VAFB, launch_site_lon_VAFB, city_lat_VAFB, city_lon_VAFB)
distance_city_marker_VAFB = folium.Marker(
  [34.94674,-120.439], # where the km value is placed
  icon=DivIcon(
    icon_size=(20,20),
    icon_anchor=(0,0),
    html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_city_VAFB)
  )
)
site_map.add_child(distance_city_marker_VAFB)
lines_city_VAFB=folium.PolyLine(locations=coordinates_city_VAFB, weight=1)
site_map.add_child(lines_city_VAFB)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# After you plot distance lines to the proximities, you can answer the following questions easily:
#
# *   Are launch sites in close proximity to railways? - Yes since the distances between the lanuch sites and railways are small.
# *   Are launch sites in close proximity to highways? - Yes since the distances between the lanuch sites and highways are small.
# *   Are launch sites in close proximity to coastline? - Yes since the distances between the lanuch sites and coastline are small.
# *   Do launch sites keep certain distance away from cities? - Yes since the distances between the lanuch sites and cities are big.
#
# Also please try to explain your findings.

# %% [markdown]
# # Next Steps:
#
# Now you have discovered many interesting insights related to the launch sites' location using folium, in a very interactive way. Next, you will need to build a dashboard using Ploty Dash on detailed launch records.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Yan Luo](https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2021-01-01)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Joseph Santarcangelo

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description          |
# | ----------------- | ------- | ---------- | --------------------------- |
# | 2021-05-26        | 1.0     | Yan        | Created the initial version |

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
